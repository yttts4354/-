# %% [markdown]
# <a href="https://colab.research.google.com/github/frogyunmax/-/blob/master/climate/1_climate_ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Use pandas

# %%
import netCDF4 
import pandas as pd

url = '/content/drive/MyDrive/PlanetA/#1/data/train/data-1996-06-09-01-1_0.nc'
nc = netCDF4.Dataset(url)

lat = nc.variables['lat']
lon = nc.variables['lon']

data_pd = pd.DataFrame(nc, index = lat, columns = lon)

# %%
data_pd.head()
# Out:
#                                                      0.0000    \
# -90.000000  <class 'netCDF4._netCDF4.Dataset'>\nroot group...
# -89.765319  <class 'netCDF4._netCDF4.Dataset'>\nroot group...
# -89.530639  <class 'netCDF4._netCDF4.Dataset'>\nroot group...
# -89.295958  <class 'netCDF4._netCDF4.Dataset'>\nroot group...
# -89.061278  <class 'netCDF4._netCDF4.Dataset'>\nroot group...
#
#                                                      0.3125    \
# -90.000000  <class 'netCDF4._netCDF4.Dataset'>\nroot group...
# -89.765319  <class 'netCDF4._netCDF4.Dataset'>\nroot group...
# -89.530639  <class 'netCDF4._netCDF4.Dataset'>\nroot group...
# -89.295958  <class 'netCDF4._netCDF4.Dataset'>\nroot group...
# -89.061278  <class 'netCDF4._netCDF4.Dataset'>\nroot group...
#
#                                                      0.6250    \
# -90.000000  <class 'netCDF4._netCDF4.Dataset'>\nroot group...
# -89.765319  <class 'netCDF4._netCDF4.Dataset'>\nroot group...
# ...

# %%
data_pd.iloc[0, 0].variables['T500'][:]
# Out:
# masked_array(
#   data=[[[230.66447, 230.66447, 230.66447, ..., 230.66447, 230.66447,
#           230.66447],
#          [230.81566, 230.81439, 230.8131 , ..., 230.81937, 230.81813,
#           230.81691],
#          [230.95218, 230.95067, 230.94911, ..., 230.956  , 230.95482,
#           230.95358],
#          ...,
#          [248.72925, 248.72911, 248.72897, ..., 248.72969, 248.72948,
#           248.72942],
#          [249.18866, 249.1883 , 249.18793, ..., 249.18964, 249.18927,
#           249.18903],
#          [249.41225, 249.41225, 249.41225, ..., 249.41225, 249.41225,
#           249.41225]]],
#   mask=False,
#   fill_value=1e+20,
#   dtype=float32)

# %% [markdown]
# Use xarray

# %%
import netCDF4
import xarray as xr

url = '/content/drive/MyDrive/PlanetA/#1/data/train/data-1996-06-09-01-1_0.nc'
data_xr = xr.open_dataset(url)

# %%
data_xr.T200[0, 0, 1151]
# Out:
# <xarray.DataArray 'T200' ()>
# array(194.6577, dtype=float32)
# Coordinates:
#     lat      float64 -90.0
#     lon      float64 359.7
#     time     <U23 'data-1996-06-09-01-1.nc'
# Attributes:
#     description:  temperature at 200 mbar pressure surface
#     units:        K

# %%
data_xr.LABELS[0, 1151]
# Out:
# <xarray.DataArray 'LABELS' ()>
# array(0)
# Coordinates:
#     lat      float64 -90.0
#     lon      float64 359.7
# Attributes:
#     description:  0: Background, 1: Tropical Cyclone, 2: Athmospheric river
